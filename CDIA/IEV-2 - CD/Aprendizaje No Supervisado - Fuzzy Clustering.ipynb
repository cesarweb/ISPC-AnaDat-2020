# %% [markdown]
# # Aprendizaje no supervisado (Unsupervised Learning)
#
# Cuando un modelo aprende patrones y comparte la información, requiere datos precisos para ayudar a la máquina a aprender esos patrones. De esto se trata el **Machine Learning**. *Con varias técnicas y métodos, se entrena a la máquina para que pueda realizar tareas usando inteligencia artificial*.
#
# Se Enfrenta varios desafíos al entrenar los modelos. No se puede encontrar datos etiquetados con precisión para alimentar el modelo. Además, los datos cuestan mucho y, a veces, no funcionan como se necesita.
# Otra técnica que aún no tiene tanta popularidad, y que en un futuro se espera que avance, es el **aprendizaje no supervisado**.
#
# Esta técnica de aprendizaje no incluye datos con etiquetas o patrones. En su lugar, se proporciona al modelo **cantidad limitada de datos sin procesar**.
#
# Como no hay que supervisar ni compartir datos etiquetados con el modelo. En cambio, el algoritmo del modelo comprenderá automáticamente y comenzará a aprender de los datos sin orientación. El modelo utilizará los datos no etiquetados para identificar nuevos patrones e información debido al diseño de su algoritmo. Con este método, podemos encontrar información nueva y no identificada previamente.
#
# Este tipo de comportamiento de aprendizaje es similar al de los humanos. Analizamos y **observamos el entorno para recopilar datos y comprender y reconocer cosas**. De manera similar, las máquinas con algoritmo de aprendizaje no supervisado descubren patrones para encontrar resultados útiles.
#
#
# `El sistema puede identificar la diferencia entre gatos y perros al comprender las habilidades y características de los animales.`
#
# Hay un proceso definido de trabajo para la salida en un algoritmo de aprendizaje no supervisado. Estos son algunos de los pasos para que funciones este algoritmmo:
#
# > • Este algoritmo explorará la estructura de datos y definirá su propio patrón.
#
# > • Extraerá información útil que se pueda utilizar para analizar el resultado.
#
# > • Ayudará a que el proceso de toma de decisiones sea productivo.
#
#
# Este algoritmo describe la información e identifica las categorías para que pueda comprender fácilmente los datos.
#
# Hay dos técnicas principales para aplicar s¿esta técnica de aprendizaje no supervisado.
#
# > • Clustering.
#
# > • Dimensionality Reduction.
#
# > • Association Rule Learning.

# %% [markdown]
# ## Association Rule Learning (Aprendizaje de reglas de asociación)
#
# Es una técnica de aprendizaje automático basada en reglas, que se utiliza para encontrar relaciones y asociaciones interesantes, ocultas en grandes conjuntos de datos. Esta regla muestra la frecuencia con la que se produce un conjunto de elementos en un conjunto de datos o una transacción.
#
# El análisis basado en el mercado, es uno de los métodos importantes utilizados por las grandes relaciones para mostrar asociaciones entre artículos. Dado un conjunto de transacciones o conjunto de datos, podemos encontrar reglas que predecirán la ocurrencia de un elemento específico en función de las ocurrencias de otros elementos en el conjunto de datos.
#
# Funciona con el concepto de declaraciones if/then *(si/entonces)*. Estas declaraciones exponen las asociaciones y relaciones entre datos independientes y datos relacionales o de otro tipo en el conjunto de datos. Estas reglas se utilizan para identificar las relaciones entre los objetos o elementos que generalmente se utilizan juntos.
#
# Los dos patrones o funciones básicos utilizados en el aprendizaje de reglas de asociación son el Support*(soporte)* y la Confidence*(confianza)*. El método identifica similitudes y reglas formadas al descomponer datos en patrones frecuentes de if/then. Las reglas de asociación generalmente se usan para satisfacer un soporte mínimo especificado por el usuario y una resolución o determinación mínima especificada por el usuario simultáneamente.
#
# **Support*(soporte)***
# El soporte indica la frecuencia con la que aparece un elemento o conjunto de elementos en el conjunto de datos o la transacción.
#
# **Confidence*(confianza)***
# La confianza indica con qué frecuencia se encuentra que una regla es verdadera.
#
# **Lift*(Mejora de la confianza)***
# Lift (A →B) indica el aumento en la probabilidad de ocurrencia de B cuando A ya ha ocurrido.
#
# El soporte y la confianza se calculan para superar el problema en el que algunos patrones en los datos pueden ocurrir por casualidad sin ninguna asociación. El apoyo es una medida importante porque una regla que tiene un apoyo muy bajo puede ocurrir simplemente por casualidad. Además, una regla de soporte bajo también es menos valiosa desde la perspectiva comercial, ya que puede no ser rentable promocionar artículos que los clientes rara vez compraran juntos.
#
# La confianza calcula la confiabilidad de la inferencia o interpretación hecha por una regla.
#
# Para una regla, si {A} →{B} tiene una confianza alta, entonces indica que es más probable que B ocurra con A.
#
# Para la regla {A} →{B}
#
# Al calcular el soporte, sabemos si la regla es importante o no.
#
# Al calcular la confianza, podemos saber la probabilidad de que A y B ocurran juntos.
#
# Aunque estos cálculos son importantes, no nos dan ninguna idea de en qué medida la aparición de un elemento (digamos A) o conjunto de elementos aumenta la aparición del otro elemento (digamos B) o conjunto de elementos.
#
# Entonces, tenemos que calcular la elevación, para saber cómo se relacionan entre sí el antecedente (elemento o dato independiente) y el consecuente (dato dependiente).
#
# Para una regla: {Antecedente} →{Consecuente}
#
# Si Lift = 1, entonces la posibilidad de ocurrencia de Antecedente y Consecuente no depende el uno del otro.
#
# Si Lift < 1, entonces la ocurrencia de Antecedente tiene un efecto negativo sobre la ocurrencia de Consecuente y el Antecedente tiene un efecto positivo sobre la ocurrencia de Consecuente.
#
# Si Lift > 1, entonces las dos ocurrencias son dependientes entre sí, y estas reglas son muy útiles para identificar el consecuente en casos finales. También nos ayuda a saber en qué medida las ocurrencias dependen unas de otras.
#
# Existen diferentes algoritmos que se utilizan para implementar la técnica de aprendizaje de reglas de asociación.
#
# **Apriori Algorithm*(Algoritmo a priori)***
# El algoritmo a priori es estándar en el aprendizaje de reglas de asociación en minería de datos. Se utiliza para dibujar conjuntos de elementos familiares y sus reglas de asociación relevantes. Está diseñado para funcionar en una base de datos.
#
# Es muy importante para un Análisis en las compras sea eficaz y ayuda a comprender al empresario qué artículos comprarán juntos los clientes. También se ha utilizado en el campo de la salud para el descubrimiento de reacciones adversas a medicamentos. Genera reglas de asociación que muestran cuáles son todas las combinaciones de medicamentos y características del paciente que ayudarán en la administración efectiva de medicamentos.
#
# **Eclat Algorithm*(Algoritmo Eclat)***
# El algoritmo Eclat se puede aplicar para lograr la minería de **itemsets** *(conjuntos de elementos)*. La minería de conjuntos de elementos nos ayuda a obtener patrones periódicos en los datos. Por ejemplo, si un consumidor compra zapatos, también compraría calcetines.
# El objetivo principal de este algoritmo es utilizar intersecciones de conjntos para calcular el soporte de un conjunto de elementos candidato evitando la generación de subconjuntos que no existen en el árbol de prefijos.
#
# El algoritmo de Eclat realiza una **depth-first search*(búsqueda en profundidad)*** para contar el número de columnas. Por lo tanto, el algoritmo Eclat funciona más rápido que el algoritmo Apriori.
#
# **F-P Growth Algorithm*(Algoritmo de crecimiento F-P)***
# La forma completa del algoritmo de crecimiento F-P es el algoritmo de crecimiento de patrones frecuentes. La clasificación FP Growth se usa solo con bases de datos pero no con flujos. El algoritmo a priori necesita n+1 número de escaneos si se utiliza una base de datos, aquí n es la longitud del modelo más largo. Podemos disminuir el número de escaneos de la base de datos completa en dos utilizando el algoritmo de crecimiento F-P.
#
# **Aplicaciones**
# *Análisis de datos del Carro de compra*: ya sea que planifique la colocación de productos en una tienda, realice una campaña de marketing o diseñe un catálogo comercial.
#
# *Minado del uso web y detección de intrusos*: para encontrar estas correlaciones ocultas es una poderosa herramienta predictiva al descubrir nuevas amenazas de seguridad y problemas de rendimiento de la red que no han sido analizados primero por un ser humano.
#
# *Bioinformática*: desde la biología hasta la ingeniería y todo lo demás, es una de las herramientas fundamentales para detectar técnicas pasadas por alto y potencialmente útiles.

# %% [markdown]
# ### **Apriori Algorithm*(Algoritmo a priori)***
# El algoritmo a priori es estándar en el aprendizaje de reglas de asociación en minería de datos. Se utiliza para dibujar conjuntos de elementos familiares y sus reglas de asociación relevantes. Está diseñado para funcionar en una base de datos.
#
# Es muy importante para un Análisis en las compras sea eficaz y ayuda a comprender al empresario qué artículos comprarán juntos los clientes. También se ha utilizado en el campo de la salud para el descubrimiento de reacciones adversas a medicamentos. Genera reglas de asociación que muestran cuáles son todas las combinaciones de medicamentos y características del paciente que ayudarán en la administración efectiva de medicamentos.

# %% [markdown]
# #### **Ventajas**
# Algoritmo fácil de entender
# Los pasos de unión y eliminación son fáciles de implementar en grandes conjuntos de elementos en grandes bases de datos

# %% [markdown]
# ### **Eclat Algorithm*(Algoritmo Eclat)***
# El algoritmo Eclat se puede aplicar para lograr la minería de **itemsets** *(conjuntos de elementos)*. La minería de conjuntos de elementos nos ayuda a obtener patrones periódicos en los datos. Por ejemplo, si un consumidor compra zapatos, también compraría calcetines.
# El objetivo principal de este algoritmo es utilizar intersecciones de conjntos para calcular el soporte de un conjunto de elementos candidato evitando la generación de subconjuntos que no existen en el árbol de prefijos.
#
# El algoritmo de Eclat realiza una **depth-first search*(búsqueda en profundidad)*** para contar el número de columnas. Por lo tanto, el algoritmo Eclat funciona más rápido que el algoritmo Apriori.

# %% [markdown]
# #### **Ventajas**
# > **Requisitos de memoria**: dado que el algoritmo ECLAT utiliza un enfoque de búsqueda en profundidad, utiliza menos memoria que el algoritmo Apriori.
#
# > **Velocidad**: el algoritmo ECLAT suele ser más rápido que el algoritmo Apriori.
#
# > **Número de cálculos**: el algoritmo ECLAT no implica el escaneo repetido de los datos para calcular los valores de soporte individuales.

# %% [markdown]
# ### **F-P Growth Algorithm*(Algoritmo de crecimiento F-P)***
# La forma completa del algoritmo de crecimiento F-P es el algoritmo de crecimiento de patrones frecuentes. La clasificación FP Growth se usa solo con bases de datos pero no con flujos. El algoritmo a priori necesita n+1 número de escaneos si se utiliza una base de datos, aquí n es la longitud del modelo más largo. Podemos disminuir el número de escaneos de la base de datos completa en dos utilizando el algoritmo de crecimiento F-P.

# %% [markdown]
# #### **Ventajas**
# FP-Growth es más rápido que Apriori.

# %% [markdown]
# ### **Desventajas**
# Requiere un alto cálculo si los conjuntos de elementos son muy grandes y el soporte mínimo se mantiene muy bajo.
# Es necesario escanear toda la base de datos.

# %% [markdown]
# ### **Aplicaciones**
# *Análisis de datos del Carro de compra*: ya sea que planifique la colocación de productos en una tienda, realice una campaña de marketing o diseñe un catálogo comercial.
#
# *Minado del uso web y detección de intrusos*: para encontrar estas correlaciones ocultas es una poderosa herramienta predictiva al descubrir nuevas amenazas de seguridad y problemas de rendimiento de la red que no han sido analizados primero por un ser humano.
#
# *Bioinformática*: desde la biología hasta la ingeniería y todo lo demás, es una de las herramientas fundamentales para detectar técnicas pasadas por alto y potencialmente útiles.

# %% [markdown]
# ## Dimensionality Reduction (Reducción de dimensionalidad)
#
# Es el proceso de disminuir las dimensiones del conjunto de características. En machine learning, a menudo hay muchos factores o variables a través de los cuales se realiza la clasificación final. Estas variables se denominan características. Si hay un mayor número de características, será más difícil visualizar el conjunto de entrenamiento. Además, si las características son más, puede conducir a una correlación y, por lo tanto, redundante. Aquí es donde la reducción de dimensionalidad juega un papel clave al reducir el número de variables aleatorias. También se puede dividir en Feature Selection  *(seleccion de variables)* y Feature Extraction *(extracción de características)*.

# %% [markdown]
# **Curse of Dimensionality*(Maldición de dimensionalidad)***
# Significa que los problemas surgen cuando trabajamos con dimensiones altas, lo que no ocurre en dimensiones bajas. Si el número de características aumenta, el número de muestras también aumenta proporcionalmente. Más cantidad de muestras necesitan todas las diferentes combinaciones de valores de características que se representarán en nuestra muestra. Debido a esto, ciertos algoritmos tienen dificultades para entrenar modelos efectivos. Esto se conoce como la maldición de la dimensionalidad. El modelo se vuelve más complejo y conduce a un sobreajuste, si hay un aumento en el número de características. Esto da como resultado un rendimiento deficiente en los datos. Por lo tanto, para evitar el sobreajuste se emplea la reducción de dimensionalidad.
#
# La reducción de la dimensionalidad tiene dos componentes principales:

# %% [markdown]
# **Feature Selection*(Selección de variables)***
#
# Significa descubrir los subconjuntos del conjunto original de funciones para obtener subconjuntos más pequeños que se utilizaran para modelar el problema.
#
# Este método implica tres procedimientos:
#
#
# *Filter(Filtro)*,
# *Wrapped(Envoltorio)*,
# *Embedded(Incrustado)*.

# %% [markdown]
# **Feature Extraction*(Extracción de características)***
#
# Reduce los datos en un espacio dimensional alto al espacio dimensional bajo al reducir el número de dimensiones. Se emplea para crear un conjunto nuevo y más pequeño de funciones que pueden capturar la mayor parte de la información útil.
#
# La principal diferencia entre la selección de funciones y la extracción de funciones es que la extracción de funciones crea otras nuevas, mientras que la selección de funciones mantiene un subconjunto de las funciones originales.

# %% [markdown]
# #### Métodos de reducción de la dimensionalidad
#
# Hay diferentes métodos a adoptar para la reducción de la dimensionalidad:

# %% [markdown]
# ##### Principal Component Analysis - Análisis de componentes principales (PCA)

# %% [markdown]
# ###### Kernel PCA
#
# Kernel PCA es una extensión de PCA que permite la sseparacion de datos no lineales mediante el uso de kernels. La idea básica detrás de esto es proyectar los datos linealmente inseparables en un espacio dimensional superior donde se vuelve linealmente separable.

# %% [markdown]
# ###### Graph-based kernel PCA
#
# En varias aplicaciones, la información estructural está implícita en las dependencias, está disponible y puede beneficiar la tarea de reducción de dimensionalidad. Este conocimiento se puede codificar en un gráfico e incorporar.

# %% [markdown]
# ###### **Desventajas**
#
# > No ofrece resultados satisfactorios en muchos problemas supervisados de clasificación o regresión al tratarse de una técnica no supervisada.
#
# > Las nuevas coordenadas ya no son variables reales producidas por el sistema, por lo que la aplicación del PCA al conjunto de datos hace que se pierda capacidad de interpretación.
#
# > Muy influenciado por los outliers en los datos, por lo que es recomendable estudiar si los hay.

# %% [markdown]
# ##### Linear Discriminant Analysis - Análisis Discriminante Lineal (LDA)
#
# Es un algoritmo de clasificación lineal. El algoritmo implica el desarrollo de un modelo probabilístico por clase basado en la distribución específica de las observaciones para cada variable de entrada

# %% [markdown]
# ###### **Desventajas**
#
# > La clasificación de nuevas observaciones no es muy eficiente a medida que se incrementa el número de variables en el modelo.
#
# >Se acostumbra a hacer selección de variables antes de aplicar el método.
#
# > Requiere que se especifiquen los grupos del conjunto de entrenamiento del modelo con clases prefijadas.

# %% [markdown]
# ##### Generalized Discriminant Analysis - Análisis Discriminante Generalizado (GDA)
#
# Se ocupa del análisis discriminante no lineal utilizando el operador de función kernel.
#
# El método GDA proporciona un mapeo de los vectores de entrada en un espacio de características de alta dimensión. De manera similar a LDA, el objetivo de GDA es encontrar una proyección para las características en un espacio de menor dimensión maximizando la proporción de dispersión entre clases y dispersión dentro de la clase.

# %% [markdown]
# ##### Non-negative matrix factorization - Factorización no negativa de matrices (NMF)
#
# Es un grupo de algoritmos en análisis multivariado y álgebra lineal donde una matriz V se factoriza en (habitualmente) dos matrices W y H, con la propiedad de que las tres matrices no tienen elementos negativos.
#
# Esta no negatividad hace que las matrices resultantes sean más fáciles de inspeccionar.

# %% [markdown]
# ###### **Ventajas**
#
# En aplicaciones tales como el procesamiento de espectrogramas de audio o actividad muscular, la no negatividad es inherente a los datos que se consideran.
#
# Dado que el problema en general no se puede resolver exactamente, comúnmente se aproxima numéricamente.

# %% [markdown]
# ##### **Autoencoder**

# %% [markdown]
# Aprovechamos las redes neuronales para la tarea de aprendizaje de representación. Específicamente, diseñaremos una arquitectura de red neuronal tal que impongamos un cuello de botella en la red que obligue a una representación de conocimiento comprimida de la entrada original.

# %% [markdown]
# ##### **T-distributed Stochastic Neighbor Embedding(t-SNE)**

# %% [markdown]
# ###### **desventajas**
#
# > Realiza una cantidad enorme de cálculos.
#
# > Está diseñado para reducir los datos a 2 o 3 dimensiones.
#
# > No debe aplicarse si la reducción de dimensionalidad se hace a espacios d > 3.
#
# > No es un proceso totalmente determinista, por lo que, a pesar de emplear los mismos datos, los resultados pueden variar.
#
#
# >Su algoritmo no es incremental, en otras palabras, no puede aplicarse sobre un set de datos y después actualizarlo con unas pocas observaciones nuevas. Se tiene que ejecutar de nuevo todo el algoritmo incluyendo todas las observaciones (las viejas y las nuevas).

# %% [markdown]
# ##### **Uniform manifold approximation and projection (UMAP)**
#
# Se construye a partir de un marco teórico basado en la geometría riemanniana y la topología algebraica. El resultado es un algoritmo escalable práctico que se aplica a datos del mundo real.
#
# El algoritmo UMAP es competitivo con t-SNE en cuanto a calidad de visualización y podría decirse que conserva más de la estructura global con un rendimiento de tiempo de ejecución superior. Además, no tiene restricciones computacionales en la dimensión incrustada, lo que lo hace viable como una técnica de reducción de dimensión de propósito general.

# %% [markdown]
# ###### **Desventajas**
#
# El algoritmo en sí se basa en tres suposiciones sobre los datos:
#
# > Los datos se distribuyen uniformemente en la variedad de Riemann.
#
# > La métrica de Riemann es localmente constante o puede aproximarse como tal.
# > El mainfold está conectado localmente.
#
# A partir de estos supuestos, es posible obtener datos no precisos.

# %% [markdown]
# ### **Ventajas**
#
# Ayuda a comprimir los datos y reduce el espacio de almacenamiento.
# Elimina el ruido, lo que resultará en una mejora del rendimiento de los modelos.
# El consumo de tiempo para los cálculos será menor ya que hay menos dimensiones.

# %% [markdown]
# ## Clustering (Agrupamiento)
#
# El término clustering hace referencia a un amplio abanico de técnicas no supervisadas cuya finalidad es encontrar patrones o grupos (clusters) dentro de un conjunto de observaciones. Las particiones se establecen de forma que, las observaciones que están dentro de un mismo grupo, son similares entre ellas y distintas a las observaciones de otros grupos.
#
# Dada la utilidad del clustering en disciplinas muy distintas (genómica, marketing…), se han desarrollado multitud de variantes y adaptaciones de sus métodos y algoritmos. Pueden diferenciarse tres grupos principales:
#
# Partitioning Clustering: Este tipo de algoritmos requieren que el usuario especifique de antemano el número de clusters que se van a crear (**K-means**, **K-medoids**, **CLARA**).
#
# Hierarchical Clustering: Este tipo de algoritmos no requieren que el usuario especifique de antemano el número de clusters. (**agglomerative clustering**, **divisive clusterig**).
#
# Métodos que combinan o modifican los anteriores (**hierarchical K-means, fuzzy clustering, model based clustering y density based clustering**).
#
# En el entorno de programación R existen múltiples paquetes que implementan algoritmos de clustering y funciones para visualizar sus resultados.
#
#
# En el entorno de programación R:
# ```
# stats: contiene las funciones dist() para calcular matrices de distancias,kmeans(), hclust(), cuttree() para crear los clusters y plot.hclust() para visualizar los resultados.
#
# cluster, mclust: contienen múltiples algoritmos de clustering y métricas para evaluarlos.
#
# factoextra: extensión basada en ggplot2 para crear visualizaciones de los resultados de clustering y su evaluación.
#
# dendextend: extensión para la customización de dendrogramas.
# ```
#
# En Python:
# ```
# La librería Scikit Learn contiene implementaciones en Python de los principales algoritmos de clustering.
# ```
#
# Todos los métodos de clustering tienen una cosa en común, para llevar a cabo las agrupaciones necesitan definir y cuantificar la similitud entre las observaciones. El término distancia se emplea dentro del contexto del clustering como cuantificación de la similitud o diferencia entre observaciones. Si se representan las observaciones en un espacio  p  dimensional, siendo  p  el número de variables asociadas a cada observación, cuando más se asemejen dos observaciones más próximas estarán, de ahí que se emplee el término distancia.
#
# **Distancia euclídea**
# La distancia euclídea entre dos puntos  p  y  q  se define como la longitud del segmento que une ambos puntos.
#
# **Distancia de Manhattan**
# La distancia de Manhattan, también conocida como taxicab metric, rectilinear distance o L1 distance, define la distancia entre dos puntos p y q como la sumatoria de las diferencias absolutas entre cada dimensión.
#
# **Correlación**
# Es una medida de distancia muy útil cuando la definición de similitud se hace en términos de patrón o forma y no de desplazamiento o magnitud.
#
# **Correlación Jackknife**
# consiste en calcular todos los posibles coeficientes de correlación entre dos variables si se excluye cada vez una de las observaciones. El promedio de todas las Jackknife correlations atenúa en cierta medida el efecto de las observaciones anormales.
#
# **Simple matching coefficient**
# Cuando las variables con las que se pretende determinar la similitud entre observaciones son de tipo binario, a pesar de que es posible codificarlas de forma numérica como  1  o  0 , no tiene sentido aplicar operaciones aritméticas sobre ellas (media, suma...). Por ejemplo, si la variable sexo se codifica como  1  para mujer y  0  para hombre, carece de significado decir que la media de la variable sexo en un determinado set de datos es  0.5 . En situaciones como esta, no se pueden emplear medidas de similitud basadas en distancia euclídea, manhattan, correlación...
#
# **Índice Jaccard**
# El índice Jaccard o coeficiente de correlación Jaccard es similar al simple matching coefficient (SMC). La diferencia radica en que, SMC considera como coincidencias tanto si el atributo está presente en ambos sets como si el atributo no está en ninguno de los sets, mientras que Jaccard solo cuenta como coincidencias cuando el atributo está presente en ambos sets.
#
# **Distancia coseno**
# El coseno del ángulo que forman dos vectores puede interpretarse como una medida de similitud de sus orientaciones, independientemente de sus magnitudes.
#
# **Escalado de las variables**
# La escala en la que se miden las variables y la magnitud de su varianza pueden afectar a los resultados obtenidos por clustering. Si una variable tiene una escala mucho mayor que el resto, determinará en gran medida el valor de distancia/similitud obtenido al comparar las observaciones, dirigiendo así la agrupación final. Escalar y centrar las variables antes de calcular la matriz de distancias para que tengan media 0 y desviación estándar 1, asegura que todas las variables tengan el mismo peso cuando se realice el clustering.
#
# **Número óptimo de clusters**
# Determinar el número óptimo de clusters es uno de los pasos más complicados a la hora de aplicar métodos de clustering, sobre todo cuando se trata de partitioning clustering, donde el número se tiene que especificar antes de poder ver los resultados. No existe una forma única de averiguar el número adecuado de clusters. Es un proceso bastante subjetivo que depende en gran medida del algoritmo empleado y de si se dispone de información previa sobre los datos con los que se está trabajando.
#
# **Método Elbow**
# El método Elbow, también conocido como método del codo, sigue una estrategia comúnmente empleada para encontrar el valor óptimo de un hiperparámetro. La idea es probar un rango de valores del hiperparámetro en cuestión, representar gráficamente los resultados obtenidos con cada uno, e identificar aquel punto de la curva (codo) a partir del cual la mejora deja de ser notable. En el caso de K-means, las observaciones se agrupan minimizazando la varianza total intra-cluster. El método Elbow calcula la varianza total intra-cluster en función del número de clusters y escoge como óptimo aquel valor a partir del cual añadir más clusters apenas consigue mejoría.
#
# **Método average silhouette**
#
# El método de average silhouette considera como número óptimo de clusters aquel que maximiza la media del silhouette coeficient de todas las observaciones.
#
# El silhouette coeficient (Si) cuantifica que tan buena es la asignación que se ha hecho de una observación comparando su similitud con el resto de observaciones de su cluster frente a las de los otros clusters. Su valor puede estar entre -1 y 1, siendo valores próximos a 1 un indicativo de que la observación se ha asignado al cluster correcto.
#
# **Estadístico gap**
# Este estadístico compara, para diferentes valores de k, la varianza total intra-cluster observada frente al valor esperado acorde a una distribución uniforme de referencia. La estimación del número óptimo de clusters es el valor k con el que se consigue maximizar el estadístico gap, es decir, encuentra el valor de k con el que se consigue una estructura de clusters lo más alejada posible de una distribución uniforme aleatoria.

# %% [markdown]
# ## **K-means**
# El método K-means clustering (MacQueen, 1967) agrupa las observaciones en K clusters distintos, donde el número K lo determina el analista antes de ejecutar del algoritmo. K-means clustering encuentra los K mejores clusters, entendiendo como mejor cluster aquel cuya varianza interna (intra-cluster variation) sea lo más pequeña posible. Se trata por lo tanto de un problema de optimización, en el que se reparten las observaciones en K clusters de forma que la suma de las varianzas internas de todos ellos sea lo menor posible. Para poder solucionar este problema es necesario definir un modo de cuantificar la varianza interna.

# %% [markdown]
# ### **Ventajas**
#
# K-means es uno de los métodos de clustering más utilizados. Destaca por la sencillez y velocidad de su algoritmo.

# %% [markdown]
# ### **desventajas**
#
# > Requiere que se indique de antemano el número de clusters que se van a crear. Esto puede ser complicado si no se dispone de información adicional sobre los datos con los que se trabaja.
#
# > Se han desarrollado varias estrategias para ayudar a identificar potenciales valores óptimos de K (elbow, shilouette), pero todas ellas son orientativas.
#
# > Dificultad para detectar clusters alargados o con formas irregulares.
#
# > Las agrupaciones resultantes pueden variar dependiendo de la asignación aleatoria inicial de los centroides. Para minimizar este problema, se recomienda repetir el proceso de clustering entre 25-50 veces y seleccionar como resultado definitivo el que tenga menor suma total de varianza interna. Aun así, solo se puede garantizar la reproducibilidad de los resultados si se emplean semillas.
#
# > Presenta problemas de robustez frente a outliers. La única solución es excluirlos o recurrir a otros métodos de clustering más robustos como K-medoids (PAM).

# %% [markdown]
# ## **K-medoids**
# Es un método de clustering muy similar a K-means en cuanto a que ambos agrupan las observaciones en K clusters. La diferencia es que, en K-medoids, cada cluster está representado por una observación presente en el cluster (medoid), mientras que en K-means cada cluster está representado por su centroide, que se corresponde con el promedio de todas las observaciones del cluster pero con ninguna en particular.
#
# El elemento dentro de un cluster cuya distancia (diferencia) promedio entre él y todos los demás elementos del mismo cluster es lo menor posible. Se corresponde con el elemento más central del cluster y por lo tanto puede considerarse como el más representativo. El hecho de utilizar medoids en lugar de centroides hace de K-medoids un método más robusto que K-means, viéndose menos afectado por outliers o ruido. El algoritmo más empleado para aplicar K-medoids se conoce como PAM (Partitioning Around Medoids)

# %% [markdown]
# ### **Ventajas**
#
# K-medoids es más adecuado cuando el set de datos contiene outliers o ruido.

# %% [markdown]
# ### **Desventajas**
# > Necesita que se especifique de antemano el número de clusters que se van a crear.
#
# > Para sets de datos grandes necesita muchos recursos computacionales. En tal situación se recomienda aplicar el método CLARA.

# %% [markdown]
# ## **CLARA**
# El método K-medoids-clustering requiere mucha memoria RAM, lo que impide que se pueda aplicar cuando el set de datos contiene varios miles de observaciones. CLARA (Clustering Large Applications) es un método que combina la idea de K-medoids con el resampling para que pueda aplicarse a grandes volúmenes de datos.
# En lugar de intentar encontrar los medoids empleando todos los datos a la vez, CLARA selecciona una muestra aleatoria de un tamaño determinado y le aplica el algoritmo de PAM (K-medoids) para encontrar los clusters óptimos acorde a esa muestra. Utilizando esos medoids se agrupan las observaciones de todo el set de datos. La calidad de los medoids resultantes se cuantifica con la suma total de las distancias entre cada observación del set de datos y su correspondiente medoid (suma total de distancias intra-clusters). CLARA repite este proceso un número predeterminado de veces con el objetivo de reducir el bias de muestreo. Por último, se seleccionan como clusters finales los obtenidos con aquellos medoids que han conseguido menor suma total de distancias.

# %% [markdown]
# ###### **Ventajas**
#
# > Capacidad para manejar grandes conjuntos de datos.
#
# > Capacidad para manejar valores atípicos.

# %% [markdown]
# ### **Desventajas**
#
# > La eficiencia está influenciada por el valor de k y el tamaño de la muestra.
#
# > La calidad del agrupamiento depende de la calidad del método de muestreo que se utilice.
#
# > Difícil de implementar.

# %% [markdown]
# ## **Hierarchical clustering**
# Hierarchical clustering es una alternativa a los métodos de partitioning clustering que no requiere que se pre-especifique el número de clusters.
#
# Dependiendo de la estrategia seguida podemos agruparlos en:
#
# > Agglomerative clustering (bottom-up): el agrupamiento se inicia en la base del árbol, donde cada observación forma un cluster individual. Los clusters se van combinado a medida que la estructura crece hasta converger en una única “rama” central.
#
# > Divisive clustering (top-down): Se inicia con todas las observaciones contenidas en un mismo cluster y se suceden divisiones hasta que cada observación forma un cluster individual.
#
# En ambos casos, los resultados pueden representarse de forma muy intuitiva en una estructura de árbol llamada dendrograma.

# %% [markdown]
# ### **Hierarchical K-means clustering**
# Una forma de contrarrestar la iinicializacion aleatoria y la seleccion de K es combinando el K-means con el hierarchical clustering.
#
# Aplicar hierarchical clustering a los datos y cortar el árbol en k clusters(optimo).
# Calcular el centro (por ejemplo, la media) de cada cluster.
# Aplicar k-means clustering empleando como centroides iniciales los centros calculados.
#
# *El algoritmo de K-means tratará de mejorar la agrupación hecha por el hierarchical clustering.*

# %% [markdown]
# ## **Density based clustering (DBSCAN)**
# Density-based spatial clustering of applications with noise (DBSCAN) fue presentado en 1996 por Ester et al. como una forma de identificar clusters siguiendo el modo intuitivo en el que lo hace el cerebro humano, identificando regiones con alta densidad de observaciones separadas por regiones de baja densidad.
#
# Los métodos de partitioining clustering como k-means, hierarchical, k-medoids, c-means… son buenos encontrando agrupaciones con forma esférica o convexa que no contengan un exceso de outliers o ruido, pero fallan al tratar de identificar formas arbitrarias.
#
# DBSCAN evita este problema siguiendo la idea de que, para que una observación forme parte de un cluster, tiene que haber un mínimo de observaciones vecinas dentro de un radio de proximidad y de que los clusters están separados por regiones vacías o con pocas observaciones.
#
# El algoritmo DBSCAN necesita dos parámetros:
#
# Epsilon (ϵ): radio que define la región vecina a una observación, también llamada ϵ-neighborhood.
#
# Minimum points (minPts): número mínimo de observaciones dentro de la región epsilon.

# %% [markdown]
# ### **Ventajas**
#
# > No requiere que el usuario especifique el número de clusters.
#
# > Es independiente de la forma que tengan los clusters, no tienen por qué ser circulares.
#
# > Puede identificar outliers, por lo que los clusters generados no sean influenciados por ellos.

# %% [markdown]
# ### **Desventajas**
# > No es un método totalmente determinístico: los border points que son alcanzables desde más de un cluster pueden asignarse a uno u otro dependiendo del orden en el que se procesen los datos.
#
# > No genera buenos resultados cuando la densidad de los grupos es muy distinta, ya que no es posible encontrar los parámetros ϵ y minPts que sirvan para todos a la vez.

# %% [markdown]
# ## **Gaussian mixture models (GMMs)**
# Es un modelo probabilístico en el que se considera que las observaciones siguen una distribución probabilística formada por la combinación de múltiples distribuciones normales (componentes). En su aplicación al clustering, puede entenderse como una generalización de K-means con la que, en lugar de asignar cada observación a un único cluster, se obtiene una probabilidad de pertenencia a cada uno.
#
# Para estimar los parámetros que definen la función de distribución de cada cluster (media y matriz de covarianza) se recurre al algoritmo de Expectation-Maximization (EM). Una vez aprendidos los parámetros, se puede calcular la probabilidad que tiene cada observación de pertenecer a cada cluster y asignarla a aquel con mayor probabilidad.

# %% [markdown]
# ## **Clustering de perfiles genéticos**
#
# Uno de los estudios más frecuentes en el ámbito de los perfiles de expresión genética es lo que se conoce como sample based clustering, que consiste en agrupar muestras (tumores, pacientes…) en base a los niveles de expresión de múltiples genes. Aunque los métodos de clustering convencionales como K-means o hierarchical clustering pueden aplicarse directamente empleando todos los genes disponibles (varios miles normalmente), se ha demostrado que, por lo general, solo un pequeño subgrupo de estos está realmente relacionado con la diferenciación de los grupos. A estos genes se les conoce como genes informativos. El resto de genes son irrelevantes en cuanto a la clasificación de interés y por lo tanto solo aportan ruido, perjudicando en gran medida la calidad de los resultados de clustering.
#
# Estos métodos se agrupan en dos categorías: clustering based on supervised informative gene selection y unsupervised clustering and informative gene selection.

# %% [markdown]
# ### *Clustering based on supervised informative gene selection*
#
# Esta aproximación combina la naturaleza unsupervided del clustering con métodos supervised de clasificación. Asumiendo que se conoce el verdadero grupo al que pertenece cada muestra o al menos parte de ellas.

# %% [markdown]
# ### *Unsupervised clustering and informative gene selection*
#
# Esta aproximación puede seguir dos estrategias distintas. Una en la que el proceso de selección de genes informativos y el clustering se llevan a cabo como procesos independientes (unsupervised gene selection) y otra en la que ambos procesos se combinan de forma simultánea e iterativa (interrelated clustering).

# %% [markdown]
# # Fuzzy clustering
#
# Los métodos de clustering descritos hasta ahora (K-means, hierarchical, K-medoids, CLARA…) asignan cada observación únicamente a un cluster, de ahí que también se conozcan como hard clustering. Los métodos de fuzzy clustering o soft clustering se caracterizan porque, cada observación, puede pertenecer potencialmente a varios clusters, en concreto, cada observación tiene asignado un grado de pertenencia a cada uno de los cluster.
#
# Fuzzy c-means (FCM) es uno de los algoritmos más empleado para generar fuzzy clustering. Se asemeja en gran medida al algoritmo de k-means pero con dos diferencias:
#
# El cálculo de los centroides de los clusters. La definición de centroide empleada por c-means es: la media de todas las observaciones del set de datos ponderada por la probabilidad de pertenecer a al cluster.
#
# Devuelve para cada observación la probabilidad de pertenecer a cada cluster.

# %% [markdown]
# ## Introduccion
#
# Los métodos de agrupamiento convencionales (duros) restringen que cada
# punto del conjunto de datos pertenece exactamente a un grupo. Teoría de conjuntos difusos propuesta por Zadeh [4] en 1965 dio una idea de la incertidumbre de pertenencia que fue descrita por una función de pertenencia.
#
# El uso de conjuntos difusos proporciona información de pertenencia a clases imprecisas. Aplicaciones de la teoria de conjunto difuso en el análisis de agruapmiento se propusieron tempranamente en el trabajo de Bellman, Kalaba y Zadeh y Ruspini. Estos artículos abren la puerta a la investigación en agrupamiento difuso.
#
# Nos centraremos en tres categorías: agrupación difusa basada en relaciones difusas, agrupación difusa basada en funciones objetivas, y la regla difusa generalizada k-vecino más cercano uno de los clasificadores no paramétricos.

# %% [markdown]
# Los algoritmos basados en clasificación Fuzzy son ampliamente utilizados en aplicaciones de compresión, organización y clasificación de información. En la actualidad se viene realizando investigaciones sobres la base del algoritmo FCM, en especial para la aplicación de reconocimiento de patrones para imágenes dentro del ámbito médico, y geográfico, de la misma manera para minería de datos con Fuzzy Miner y en la BIGDATA adaptando el método Fuzzy a diferentes métodos para obtener resultados robustos.

# %% [markdown]
# ### Partición difusa
# Una partición difusa es una particion que caracteriza la participación de cada muestra en todos los grupos utilizando funciones de pertenencia que toman valores entre cero y uno.
#
# Además, cumplen que para cada muestra la suma de sus participaciones en cada grupo es uno. De esta forma, es posible traducir el problema del agrupamiento difuso en encontrar una partición difusa óptima.
#
# Sea **X** = (x<sub>1</sub>,...,x<sub>n</sub>) un subconjunto de un espacio euclidiano de dimensión **s** y **c** un entero positivo mayor que uno.
#
# Una partición difusa de **X** en **c** grupos es una tupla de **c** funciones de pertenencia
# $\mu = (\mu_1, \ldots, \mu_c)$ que cumplen que:
#
# $0 \leq \mu_i(x) \leq 1, \forall i = 1,\ldots,c$
#
# $0 < \sum\limits_{j=1}^n \mu_i(x_j) < 1, \forall i$
#
# $\sum\limits_{i=1}^c \mu_i(x_j) = 1, \forall j$
#
#
# Las particiones difusas se representan como una Matriz asociando cada fila a uno de los **c** grupos y cada columna a uno de los elementos de **X**, de forma tal que el valor en la fila **i** y la columna **j** indique la pertenencia del elemento **j** al grupo **i**.
#
# Más formalmente, el conjunto de las particiones difusas se puede definir como:
# $M_{fc} = \{ U \in \Re^{c \times n}| U = [u_{ij}]; u_{ij} \in [0,1] \forall i,j; \sum\limits_{i=1}^c u_{ij} = 1 \forall j; \sum\limits_{j=1}^n u_{ij} > 0 \forall i \}$

# %% [markdown]
# ### Algoritmos Fuzzy **C**-Means
#
# Son algunos de los principales algoritmos utilizados en el agrupamiento difuso y pertenecen a una clase de algoritmos basados en funciones objetivo.
#
# Estos algoritmos definen un criterio de agrupamiento en la forma de una función objetivo que depende de la partición difusa.
#
# El procedimiento, en sentido general, consiste en minimizar iterativamente esta función hasta obtener una partición difusa óptima.
#
# Se han propuesto varios criterios de agrupamiento para obtener la partición difusa óptima para **X**, pero el más popular hasta el momento está asociado con la función de error mínimo cuadrático.
#
# $J_m(U,v) = \sum\limits_{k=1}^n \sum\limits_{i=1}^c (u_{ik})^m d_{ik}^2 $
#
# El valor $d_{ik}^2$ indica la distancia cuadrada entre los elementos de **X** y
# los centros de los grupos y puede calcularse utilizando la siguiente fórmula:
# $d_{ik}^2 = ||x_k - v_i||_A^2 = (x_k - v_i)^T A (x_k - v_i)$
# donde:
# * $X = (x_1, x_2, \ldots, x_n) \subset \Re^s$ son los datos,
# * $v_i = (v_{i1}, v_{i2}, \ldots, v_{ic})$ es el vector centro del grupo i,
# * || ||<sub>A</sub> es la norma inducida por **A**
# * **A** es una matriz definida positiva de pesos de dimensiones $(n \times n)$
#
# En particular, si **A** es la matriz identidad, $d_{ik}^2$ es el cuadrado de la distancia euclidiana.
#
# El peso asociado a cada distancia cuadrada, $(u_{ik})^m$, es
# la **m**-ésima potencia del grado de pertenencia del **k**-ésimo dato al grupo **i**.
#
# Cuando $m \rightarrow 1$ la partición óptima es cada vez más cercana a una partición exclusiva, mientras que cuando $m \rightarrow \infty$ la
# partición óptima se aproxima a la matriz con todos sus valores iguales a (1/**c**).
#
#
# Los valores de **m** que normalmente se utilizan son valores en el intervalo [1,30].
#
# Cada selección de un valor particular de **m** marca un algoritmo Fuzzy **c**-Means específico.
#
# Teniendo esto en cuenta, el procedimiento general de los algoritmos Fuzzy **c**-Means puede formalizarse en los siguientes pasos:
#
# > Fijar **c**, **m**, **A** y ||**k**||<sub>A</sub>. Elegir una matriz inicial $U^{(0)} \in M_{fc}$.
#
# > Calcular los centros de los grupos con la fórmula $v_i = \frac{\sum\limits_{k=1}^n (u_{ik})^m x_k}{\sum\limits_{k=1}^n (u_{ik})^m}; 1 \leq i \leq c$. > Actualizar la matriz de partición difusa U = [u<sub>ik</sub>] con $u_{ik} = (\sum\limits_{j=1}^c (\frac{d_{ik}}{d_{jk}})^{\frac{2}{m-1}})^{-1}; 1 \leq k \leq n; 1 \leq i \leq c$.
#
# > Si se alcanzó el criterio de parada, terminar. En caso contrario, regresar al paso 2.
#
# Algunos de los criterios de parada más utilizados son:<ref name=bezfcm />
# * Un número máximo de iteraciones
# * Que la variación en la matriz U sea muy pequeña:
# $||U^{k+1} - U^k|| < \epsilon$.

# %% [markdown]
# # Ejemplos

# %% [markdown]
# ### R

# %%
# %load_ext rpy2.ipython

# %%
# %%R
#
# install.packages("factoextra")

# %%
# %%R
# # Carga Datos sobre el número de delitos (asaltos, asesinatos y secuestros)
# # junto con el porcentaje de población urbana para cada uno de los 50 estados de USA.
# data("USArrests")
#
# # Como la magnitud de los valores difiere notablemente entre variables, se procede
# # a escalarlas antes de aplicar el clustering.
#
# datos <- scale(USArrests)
#
# # La función fanny() (fuzzy analysis) del paquete cluster permite aplicar el algoritmo
# # c-means clustering.
#
# library(cluster)
# fuzzy_cluster <- fanny(x = datos, diss = FALSE, k = 3, metric = "euclidean", stand = FALSE)
#
# head(fuzzy_cluster$membership)
# # El objeto devuelto incluye entre sus elementos: una matriz con el grado de pertenencia
# # de cada observación a cada cluster.
# Out:
#                 [,1]      [,2]      [,3]
# Alabama    0.4676004 0.3144516 0.2179480
# Alaska     0.4278809 0.3178707 0.2542484
# Arizona    0.5092197 0.2945668 0.1962135
# Arkansas   0.2934077 0.3787718 0.3278205
# California 0.4668527 0.3084149 0.2247324
# Colorado   0.4542018 0.3236683 0.2221299

# %%
# %%R
#
# fuzzy_cluster$coeff
# # El coeficiente de partición Dunn normalizado y sin normalizar.
# # norm -> 0 alto nivel fuzzy y valores próximos a 1 lo contrario.
# Out:
# dunn_coeff normalized
# 0.37371071 0.06056606

# %%
# %%R
# # El cluster al que se ha asignado mayoritariamente cada observación.
# head(fuzzy_cluster$clustering)
# Out:
#    Alabama     Alaska    Arizona   Arkansas California   Colorado
#          1          1          1          2          1          1

# %%
# %%R
# # Representacion Grafica
# library(factoextra)
# fviz_cluster(object = fuzzy_cluster, repel = TRUE, ellipse.type = "norm", pallete = "jco") + theme_bw() + labs(title = "Fuzzy Cluster plot")
# Out:
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]: Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa

# %% [markdown]
# ### Python

# %%
# !pip install fuzzy-c-means

# %%
# %matplotlib inline
import numpy as np
from fcmeans import FCM
from matplotlib import pyplot as plt

# creating artificial data set

n_samples = 3000

X = np.concatenate((
    np.random.normal((-2, -2), size=(n_samples, 2)),
    np.random.normal((2, 2), size=(n_samples, 2))
))

plt.figure(figsize=(5, 5))
plt.scatter(X[:,0], X[:,1], alpha=.1)
plt.show()

# %%
# outputs
fcm_centers = fcm.centers
fcm_labels = fcm.predict(X)

# plot result
f, axes = plt.subplots(1, 2, figsize=(11,5))
axes[0].scatter(X[:,0], X[:,1], alpha=.1)
axes[1].scatter(X[:,0], X[:,1], c=fcm_labels, alpha=.1)
axes[1].scatter(fcm_centers[:,0], fcm_centers[:,1], marker="+", s=500, c='w')
# plt.savefig('images/basic-clustering-output.jpg')
plt.show()

# %% [markdown]
# # Bibliografía
#
# https://www.i2tutorials.com/machine-learning-tutorial
#
# https://www.cienciadedatos.net/documentos/py20-clustering-con-python.html
#
# https://www.cienciadedatos.net/documentos/37_clustering_y_heatmaps#Fuzzy_clustering
#
# A Survey of Fuzzy Clustering M.-S. YANG 1993
#
# Fundamentals of Fuzzy Clustering Rudolf Kruse, Christian Do¨ring, and Marie-Jeanne Lesot.
#
# Fuzzy Clustering: Insights and a New Approach F. Klawonn 2004
#
# Possibilistic and fuzzy clustering methods for robust analysis of non-precise data Maria Brigida Ferraro, Paolo Giordani
