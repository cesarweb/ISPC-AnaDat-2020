# %% [markdown]
# # **Fundamentals of (FCMF) Fuzzy Clustering framework**
#
# ### Abstract
# Based on the theoretical concept of frameworks applied to the academic field, My FCM framework has been created, through the implementation of the Methodology for the Collaborative Testing of the well known fuzzy clustering algorithm. This paper allowed us to address the problem of keeping track of the combination of multiple parameters used in this algorithm, acquiring diverse benefits in the access of information and ease to use.
#
#     ***Keywords*** *Fuzzy c-Means, Collaborative development, Framework*

# %% [markdown]
# # 1 Introduction
#
# Clustering is an exploratory data analysis technique and is applied in the data
# analysis process at a state where no precise model of the data is known.
#
# Therefore, it is necessary that the clustering process is self-guided as far as possible and will avoid unsuitable clustering results that do not reflect the structure of the data set properly.
#
# Most fuzzy clustering techniques aim at minimizing an objective function that
# usually has a number of undesired local minima.
#
# Fuzzy clustering has been extensively used to extract knowledge from data. Fuzzy c-means is one of the most used fuzzy clustering algorithms.
#
# It is a fuzzy generalization of k-means in which membership of elements to clusters is fuzzy. That is, the elements can belong to more than one cluster at the same time.
#
# Fuzzy c-means is not the only fuzzy clustering algorithm. There are several families (e.g. entropy fuzzy c-means and possibilistic clustering) and variants (e.g. variable-size fuzzy c-means).
#
# Fuzzy c-means depends mainly on two parameters. One is the number of clusters. The other is the parameter m which stands for the degree of fuzziness in
# the solution.

# %% [markdown]
# # 2 Basic Clustering Algorithms
#
# Fuzzy c-means (FCM) is a data clustering technique in which a data set is grouped into N clusters with every data point in the dataset belonging to every cluster to a certain degree.
#
# The fcm function performs FCM clustering. It starts with a initial guess for the cluster centers; that is the mean location of each cluster. Next, fcm assigns every data point a random membership grade for each cluster. By iteratively updating the cluster centers and the membership grades for each data point, fcm moves the cluster centers to the correct location within a data set and, for each data point, finds the degree of membership in each cluster. This iteration minimizes an objective function that represents the distance from any given data point to a cluster center weighted by the membership of that data point in the cluster.

# %% [markdown]
# # 3 Under The hood
#
# We use Python, Google colab and DagsHub (Git, DVC, MlFlow) to keep track of the progress of our test.
#
# We can keep track of:
#
# 1.   Number of Data N
# 2.   Number of Clusters K
# 3.   Dimension of cluster D
# 4.   Fuzzyness Parameter M
# 5.   Number of Iterations MAX_ITERS
# 6.   Initialization of Centers external_test
#
# What we want Improve:
#
# 1.   Fully Customization of initializeMembershipMatrix
# 2.   Method of Center Distances Calculations
# 3.   Customizable Control Dataset for Accuracy test

# %% [markdown]
# # 4 Python-Colab Interaction
#
# 1.  We Try for Imports (Automatic install of Requirements) and rebooting of environment.
#
# > try:
# >
# >>  import
# >
# >except ImportError as e:
# >
# >>  !pip install -q
# >
# >os.kill(os.getpid(), 9)
#
# 2.  Take Care of DagsHub Initialization and Mlflow Run
#
# > init_Dags = False
# > log_run = True
# > _run_name = "Run Number: "

# %% [markdown]
# # 5 Compare Tests and Enjoy Results
#
# ![Dags1.png](data:image/png;base64,...)![dags2.png](data:image/png;base64,...)![Dags3.png](data:image/png;base64,...)![Dags4.png](data:image/png;base64,...)

# %% [markdown]
# # 6 Bibliography
#
# https://github.com/cesarweb/ISPC-AnaDat-2020/blob/main/CDIA/IEV-2%20-%20CD/Aprendizaje%20No%20Supervisado%20-%20Fuzzy%20Clustering.ipynb
#
# https://www.salesforce.com/workdifferently/articles/how-to-design-framework/
#
# https://www.devteam.space/blog/how-to-build-a-framework/
#
# https://www.cienciadedatos.net/documentos/py20-clustering-con-python.html
#
# https://www.cienciadedatos.net/documentos/37_clustering_y_heatmaps#Fuzzy_clustering
#
# A Survey of Fuzzy Clustering M.-S. YANG 1993
#
# Fundamentals of Fuzzy Clustering Rudolf Kruse, Christian Do¨ring, and Marie-Jeanne Lesot.
#
# Fuzzy Clustering: Insights and a New Approach F. Klawonn 2004
#
# Possibilistic and fuzzy clustering methods for robust analysis of non-precise data Maria Brigida Ferraro, Paolo Giordani

# %% [markdown]
# # 7 Appendix 1 - Fuzzy C-Means Framework Latest Version:
#
# https://github.com/cesarweb/ISPC-AnaDat-2020/tree/main/CDIA/Proyecto
